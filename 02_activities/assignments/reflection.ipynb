# %% [markdown]
# Recovery of missing file
#
# This assignment helped deepen my understanding of tree traversal techniques, specifically breadth-first search (BFS) and depth-first search (DFS), in the context of binary trees. I began by exploring how BFS works by visiting nodes level by level using a queue, which was a practical way to understand search patterns and how to detect duplicates closest to the root. Implementing this logic in the is_duplicate function helped me see the value of using inline BFS for single-purpose checks, while also reinforcing the importance of using data structures like sets and queues effectively.
# BFS is best use to searh for the shortest path because it gives a good overview on the structure of the tree, in certain ways, it is more efficient.
#
# The second part of the assignment focused on using DFS to list all root-to-leaf paths. This exercise improved my understanding of recursive thinking, particularly how to manage path construction and backtracking. I learned how recursive calls build up a stack that mirrors the depth of the tree, and how to carefully control when to add paths to the result list.
# I think DFS is more compute intensive as it will need to examine each node.
#
# I started to understand how these recursive reversal framework can help with deep learning / machihne learning problems
